# %%
# !pip install faiss-cpu

# !pip install mistralai 
# !pip install openpyxl
# Out:
# Requirement already satisfied: faiss-cpu in /opt/conda/lib/python3.12/site-packages (1.10.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /opt/conda/lib/python3.12/site-packages (from faiss-cpu) (2.1.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from faiss-cpu) (24.1)
# Collecting mistralai
#   Downloading mistralai-1.5.1-py3-none-any.whl.metadata (29 kB)
# Collecting eval-type-backport>=0.2.0 (from mistralai)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: httpx>=0.27.0 in /opt/conda/lib/python3.12/site-packages (from mistralai) (0.28.0)
# Collecting jsonpath-python>=1.0.6 (from mistralai)
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pydantic>=2.9.0 in /opt/conda/lib/python3.12/site-packages (from mistralai) (2.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from mistralai) (2.9.0.post0)
# Collecting typing-inspect>=0.9.0 (from mistralai)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.0->mistralai) (4.6.2.post1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.0->mistralai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.0->mistralai) (1.0.7)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.0->mistralai) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->mistralai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.9.0->mistralai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.9.0->mistralai) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.9.0->mistralai) (4.12.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->mistralai) (1.16.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.9.0->mistralai)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->mistralai) (1.3.1)
# Downloading mistralai-1.5.1-py3-none-any.whl (278 kB)
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, jsonpath-python, eval-type-backport, typing-inspect, mistralai
# Successfully installed eval-type-backport-0.2.2 jsonpath-python-1.0.6 mistralai-1.5.1 mypy-extensions-1.0.0 typing-inspect-0.9.0
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.12/site-packages (from openpyxl) (2.0.0)

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 46.1 MB/s eta 0:00:0000:01
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: tzdata, pandas

# %%
import faiss
import numpy as np
import pandas as pd
import time
from openai import OpenAI
import pickle

# 1. Définition de la requête
query_text = "taux de change dollar états unis"

# 2. Chargement de la clé OpenAI depuis un fichier sécurisé
from credentials.keys import OPENAI_API_KEY
client = OpenAI(api_key=OPENAI_API_KEY)

# 3. Chargement du fichier Excel et préparation des données
file_path = "resultat_jointure.xlsx"  # Nom du fichier Excel
df = pd.read_excel(file_path)

#df=df.head(10)

df["title_fr"] = df["title_fr"].fillna("")
df["description_fr"] = df["description_fr"].fillna("")

def extract_periodicity(series_key):
    periodicity_mapping = {"D": "quotidien", "H": "hebdomadaire", "M": "mensuel", "A": "annuel", "Q": "trimestriel"}
    code = series_key.split(".")[1] if len(series_key.split(".")) > 1 else ""
    return periodicity_mapping.get(code, "")

df["periodicity"] = df["series_key"].apply(extract_periodicity)

documents = (df["description_fr"] + " " + df["title_fr"] + " " + df["periodicity"]).astype(str).tolist()
ids = df["series_key"].astype(str).tolist()

print("Taille des ids (fichier Excel) :", len(ids))

# 4. Création des embeddings et stockage dans FAISS
BATCH_SIZE = 200
total_tokens = 0

dim = 1536  # Taille des embeddings (doit être alignée avec le modèle utilisé)
index = faiss.IndexFlatL2(dim)  # Index FAISS pour la recherche par distance euclidienne

metadata = {}  # Stocker les ID et les métadonnées associées

print("Début de la génération des embeddings par lots de 200...")

for i in range(0, len(documents), BATCH_SIZE):
    batch_texts = documents[i : i + BATCH_SIZE]
    batch_ids = ids[i : i + BATCH_SIZE]
    
    response = client.embeddings.create(input=batch_texts, model="text-embedding-3-small")
    
    #batch_embeddings = np.array([resp.embedding for resp in response.data], dtype=np.float32)
    batch_embeddings = np.array([item.embedding for item in response.data], dtype=np.float32)

    total_tokens += response.usage.total_tokens
    
    index.add(batch_embeddings)  # Ajout des embeddings à FAISS
    
    for doc_id, text in zip(batch_ids, batch_texts):
        metadata[doc_id] = {
            "title": df.loc[df["series_key"] == doc_id, "title_fr"].values[0],
            "description": df.loc[df["series_key"] == doc_id, "description_fr"].values[0],
            "periodicity": df.loc[df["series_key"] == doc_id, "periodicity"].values[0],
            "dataset_id": df.loc[df["series_key"] == doc_id, "dataset_id"].values[0],
        }

    print(f"Batch {i // BATCH_SIZE + 1} : {len(batch_texts)} embeddings générés et ajoutés dans FAISS.")
    time.sleep(1)

print(f"Total de tokens consommés : {total_tokens}")

# Sauvegarde de l'index FAISS et des métadonnées
faiss.write_index(index, "faiss_index_openai.bin")
with open("metadata_openai.pkl", "wb") as f:
    pickle.dump(metadata, f)

print("Index FAISS et métadonnées sauvegardés.")

# 5. Générer l'embedding de la requête
response = client.embeddings.create(input=query_text, model="text-embedding-3-small")
query_embedding = np.array(response.data[0].embedding, dtype=np.float32).reshape(1, -1)

# 6. Recherche des voisins les plus proches
k = 10  # Nombre de résultats à récupérer
distances, indices = index.search(query_embedding, k)

# 7. Affichage des résultats
print("Phrase recherchée :", query_text)

for i, (distance, idx) in enumerate(zip(distances[0], indices[0])):
    if idx < len(metadata):  # Vérifier si l'index est valide
        doc_id = list(metadata.keys())[idx]
        meta_info = metadata[doc_id]
        print(f"Résultat {i+1}: {doc_id} (distance: {distance})")
        print(f"  - Titre: {meta_info['title']}")
        print(f"  - Description dataset: {meta_info['description']}")
        print(f"  - Périodicité: {meta_info['periodicity']}")
        print(f"  - Dataset: {meta_info['dataset_id']}")

# 8. Vérification d'une série particulière
specific_series_key = "EXR.D.USD.EUR.SP00.A"
if specific_series_key in metadata:
    specific_embedding = np.array(response.data[0].embedding, dtype=np.float32).reshape(1, -1)
    distance = np.linalg.norm(query_embedding - specific_embedding)
    print(f"Distance entre '{specific_series_key}' et la requête : {distance}")
else:
    print(f"L'ID '{specific_series_key}' n'existe pas dans l'index FAISS.")
# Out:
# Taille des ids (fichier Excel) : 44371
# Début de la génération des embeddings par lots de 200...
# Batch 1 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 2 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 3 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 4 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 5 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 6 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 7 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 8 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 9 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 10 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 11 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 12 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 13 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 14 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 15 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 16 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 17 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 18 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 19 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 20 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 21 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 22 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 23 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 24 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 25 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 26 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 27 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 28 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 29 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 30 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 31 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 32 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 33 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 34 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 35 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 36 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 37 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 38 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 39 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 40 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 41 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 42 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 43 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 44 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 45 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 46 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 47 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 48 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 49 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 50 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 51 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 52 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 53 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 54 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 55 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 56 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 57 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 58 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 59 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 60 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 61 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 62 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 63 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 64 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 65 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 66 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 67 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 68 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 69 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 70 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 71 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 72 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 73 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 74 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 75 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 76 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 77 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 78 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 79 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 80 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 81 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 82 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 83 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 84 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 85 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 86 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 87 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 88 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 89 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 90 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 91 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 92 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 93 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 94 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 95 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 96 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 97 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 98 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 99 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 100 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 101 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 102 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 103 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 104 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 105 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 106 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 107 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 108 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 109 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 110 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 111 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 112 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 113 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 114 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 115 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 116 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 117 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 118 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 119 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 120 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 121 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 122 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 123 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 124 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 125 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 126 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 127 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 128 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 129 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 130 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 131 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 132 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 133 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 134 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 135 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 136 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 137 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 138 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 139 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 140 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 141 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 142 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 143 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 144 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 145 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 146 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 147 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 148 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 149 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 150 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 151 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 152 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 153 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 154 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 155 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 156 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 157 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 158 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 159 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 160 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 161 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 162 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 163 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 164 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 165 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 166 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 167 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 168 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 169 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 170 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 171 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 172 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 173 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 174 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 175 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 176 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 177 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 178 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 179 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 180 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 181 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 182 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 183 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 184 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 185 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 186 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 187 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 188 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 189 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 190 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 191 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 192 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 193 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 194 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 195 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 196 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 197 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 198 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 199 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 200 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 201 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 202 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 203 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 204 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 205 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 206 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 207 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 208 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 209 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 210 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 211 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 212 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 213 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 214 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 215 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 216 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 217 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 218 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 219 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 220 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 221 : 200 embeddings générés et ajoutés dans FAISS.
# Batch 222 : 171 embeddings générés et ajoutés dans FAISS.
# Total de tokens consommés : 1948042
# Index FAISS et métadonnées sauvegardés.
# Phrase recherchée : taux de change dollar états unis
# Résultat 1: EXR.D.USD.EUR.SP00.A (distance: 0.5423344373703003)
#   - Titre: Dollar des Etats-Unis (USD)
#   - Description dataset: Taux de change des devises principales.
#   - Périodicité: quotidien
#   - Dataset: EXR
# Résultat 2: EXR.M.USD.EUR.SP00.A (distance: 0.6249432563781738)
#   - Titre: Dollar des Etats-Unis (USD)
#   - Description dataset: Taux de change des devises principales.
#   - Périodicité: mensuel
#   - Dataset: EXR
# Résultat 3: EXR.M.USD.EUR.SP00.E (distance: 0.6461151242256165)
#   - Titre: Cours de change de l'euro contre dollar des Etats-Unis (USD) - fin de mois
#   - Description dataset: Taux de change des devises principales.
#   - Périodicité: mensuel
#   - Dataset: EXR
# Résultat 4: EXR.D.CAD.EUR.SP00.A (distance: 0.8304812908172607)
#   - Titre: Dollar canadien (CAD)
#   - Description dataset: Taux de change des devises principales.
#   - Périodicité: quotidien
#   - Dataset: EXR
# Résultat 5: EXR.D.AUD.EUR.SP00.A (distance: 0.8316702842712402)
#   - Titre: Dollar australien (AUD)
#   - Description dataset: Taux de change des devises principales.
#   - Périodicité: quotidien
#   - Dataset: EXR
# Résultat 6: EXR.D.HKD.EUR.SP00.A (distance: 0.8758783340454102)
#   - Titre: Dollar de Hong Kong (HKD)
#   - Description dataset: Taux de change des devises principales.
#   - Périodicité: quotidien
#   - Dataset: EXR
# Résultat 7: EXR.M.CAD.EUR.SP00.A (distance: 0.8859622478485107)
#   - Titre: Dollar canadien (CAD)
#   - Description dataset: Taux de change des devises principales.
#   - Périodicité: mensuel
#   - Dataset: EXR
# Résultat 8: EXR.M.AUD.EUR.SP00.A (distance: 0.9007406830787659)
#   - Titre: Dollar australien (AUD)
#   - Description dataset: Taux de change des devises principales.
#   - Périodicité: mensuel
#   - Dataset: EXR
# Résultat 9: EXR.D.NZD.EUR.SP00.A (distance: 0.9041193127632141)
#   - Titre: Dollar neo-zélandais (NZD)
#   - Description dataset: Taux de change des devises principales.
#   - Périodicité: quotidien
#   - Dataset: EXR
# Résultat 10: EXR.M.CAD.EUR.SP00.E (distance: 0.9119994640350342)
#   - Titre: Cours de change de l'euro contre dollar canadien (CAD) - fin de mois
#   - Description dataset: Taux de change des devises principales.
#   - Périodicité: mensuel
#   - Dataset: EXR
# Distance entre 'EXR.D.USD.EUR.SP00.A' et la requête : 0.0
